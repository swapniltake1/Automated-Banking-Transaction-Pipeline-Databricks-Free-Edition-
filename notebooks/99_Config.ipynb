# %%
# Databricks notebook source

# COMMAND ----------
# ============================================================
# Banking Data Engineering Platform
# Notebook : 99_Config
# Purpose  : Central Configuration
# Compatible : Databricks Free Edition
# ============================================================

from datetime import datetime
from uuid import uuid4

# %%
# COMMAND ----------
# ============================================================
# Project Details
# ============================================================

PROJECT_NAME = "Banking Data Engineering Platform"

PROJECT_VERSION = "1.0"

PIPELINE_NAME = "Banking ETL Pipeline"

ENVIRONMENT = "Databricks Free Edition"

CURRENT_RUN_ID = str(uuid4())

PIPELINE_START_TIME = datetime.now()

print("Configuration Loaded Successfully")

# %%
# COMMAND ----------
# ============================================================
# Unity Catalog
# ============================================================

CATALOG_NAME = "banking_catalog"

SCHEMA_NAME = "banking_project"

VOLUME_NAME = "banking_volume"

# %%
# COMMAND ----------
# ============================================================
# Base Paths
# ============================================================

BASE_PATH = f"/Volumes/{CATALOG_NAME}/{SCHEMA_NAME}/{VOLUME_NAME}"

REFERENCE_DATA = f"{BASE_PATH}/reference_data"

INCOMING_PATH = f"{BASE_PATH}/incoming"

PROCESSED_PATH = f"{BASE_PATH}/processed"

REJECTED_PATH = f"{BASE_PATH}/rejected"

ARCHIVE_PATH = f"{BASE_PATH}/archive"

VALIDATED_PATH = f"{BASE_PATH}/validated"

BRONZE_PATH = f"{BASE_PATH}/bronze"

SILVER_PATH = f"{BASE_PATH}/silver"

GOLD_PATH = f"{BASE_PATH}/gold"

CHECKPOINT_PATH = f"{BASE_PATH}/checkpoints"

LOG_PATH = f"{BASE_PATH}/logs"

TEMP_PATH = f"{BASE_PATH}/temp"

METADATA_PATH = f"{BASE_PATH}/metadata"

# %%
# COMMAND ----------
# ============================================================
# Landing Folders
# ============================================================

LANDING_FOLDERS = [

    "incoming",

    "processed",

    "rejected",

    "archive"

]

# %%
# COMMAND ----------
# ============================================================
# Banking Source Systems
# ============================================================

SOURCE_SYSTEMS = [

    "ATM",

    "UPI",

    "NEFT",

    "RTGS",

    "CARD",

    "INTERNET_BANKING",

    "MOBILE_BANKING",

    "BRANCH"

]

# %%
# COMMAND ----------
# ============================================================
# Datasets
# ============================================================

DATASETS = [

    "transactions",

    "customers",

    "accounts",

    "branches"

]

# %%
# COMMAND ----------
# ============================================================
# Transaction Types
# ============================================================

VALID_TRANSACTION_TYPES = [

    "ATM_WITHDRAWAL",

    "UPI_TRANSFER",

    "NEFT",

    "RTGS",

    "CARD_PAYMENT",

    "IB_TRANSFER",

    "MB_TRANSFER",

    "CASH_DEPOSIT"

]

# %%
# COMMAND ----------
# ============================================================
# Audit Columns
# ============================================================

AUDIT_COLUMNS = [

    "source_system",

    "source_file",

    "pipeline_name",

    "pipeline_run_id",

    "load_date",

    "load_timestamp"

]

# %%
# COMMAND ----------
# ============================================================
# Table Names
# ============================================================

TABLES = {

    "bronze_transactions": "bronze_transactions",

    "silver_transactions": "silver_transactions",

    "gold_daily_summary": "gold_daily_summary",

    "rejected_transactions": "rejected_transactions",

    "audit_pipeline": "audit_pipeline_log"

}

# %%
# COMMAND ----------
# ============================================================
# Validation Rules
# ============================================================

MAX_TRANSACTION_AMOUNT = 1000000

MIN_TRANSACTION_AMOUNT = 1

# %%
# COMMAND ----------
# ============================================================
# Configuration Summary
# ============================================================

print("="*80)

print(f"Project        : {PROJECT_NAME}")

print(f"Version        : {PROJECT_VERSION}")

print(f"Environment    : {ENVIRONMENT}")

print(f"Catalog        : {CATALOG_NAME}")

print(f"Schema         : {SCHEMA_NAME}")

print(f"Volume         : {VOLUME_NAME}")

print(f"Pipeline       : {PIPELINE_NAME}")

print(f"Run ID         : {CURRENT_RUN_ID}")

print("="*80)
